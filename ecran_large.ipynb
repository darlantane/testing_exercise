# %%
# !pip install robotframework
# !pip install robotframework-seleniumlibrary
# !pip install webdriver-manager
# Out:
# ...
#   Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# ...
# Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# ...

# %%
robot_test = """

*** Settings ***
Library    SeleniumLibrary
Library    Collections

Suite Setup    Open Chrome With Options
Suite Teardown    Close Browser


*** Variables ***
${URL}        https://www.ecranlarge.com/
${KEYWORD}    Dune


*** Test Cases ***
Search Article And Open First Result
    Go To    ${URL}

    Accept Cookies If Present
    Open Search
    Search Keyword
    Open First Result
    Verify Article Title


*** Keywords ***
Open Chrome With Options
    ${chrome options}=    Evaluate    sys.modules['selenium.webdriver'].ChromeOptions()    sys, selenium.webdriver
    Call Method    ${chrome options}    add_argument    --disable-notifications
    Call Method    ${chrome options}    add_argument    --start-maximized

    Open Browser    about:blank    chrome    options=${chrome options}
    Set Selenium Timeout    10s


Accept Cookies If Present
    Run Keyword And Ignore Error
    ...    Wait Until Element Is Visible
    ...    css:#didomi-notice-agree-button    5s

    Run Keyword And Ignore Error
    ...    Click Element
    ...    css:#didomi-notice-agree-button


Open Search
    Wait Until Element Is Visible
    ...    css:button[aria-label="Bouton de recherche"]
    Click Element
    ...    css:button[aria-label="Bouton de recherche"]


Search Keyword
    Wait Until Element Is Visible    css:input[type="search"]
    Input Text    css:input[type="search"]    ${KEYWORD}
    Press Keys    css:input[type="search"]    ENTER


Open First Result
    Wait Until Page Contains Element    css:article
    Click Element    css:article a


Verify Article Title
    Wait Until Element Is Visible    css:h1
    ${title}=    Get Text    css:h1
    Should Not Be Empty    ${title}"""

# %%
# !robot test_ecranlarge.robot
# Out:
# ...
# Test Ecranlarge
# ...
# Search Article And Open First Result                                  | FAIL |
# ValueError: Unable to parse option: "add_argument(--disable-notifications)"
# ------------------------------------------------------------------------------
# Test Ecranlarge                                                       | FAIL |
# 1 test, 0 passed, 1 failed
# ...
# Output:  c:\Users\darla\Desktop\Ecran large\output.xml
# Log:     c:\Users\darla\Desktop\Ecran large\log.html
# Report:  c:\Users\darla\Desktop\Ecran large\report.html
