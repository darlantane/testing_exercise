# %%
# !pip install robotframework
# !pip install robotframework-seleniumlibrary
# Out:
# Collecting robotframework
#   Downloading robotframework-7.4.1-py3-none-any.whl.metadata (7.6 kB)
# Downloading robotframework-7.4.1-py3-none-any.whl (806 kB)
#    ---------------------------------------- 0.0/806.9 kB ? eta -:--:--
#    --------------------------------------- 806.9/806.9 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: robotframework
# Successfully installed robotframework-7.4.1
# Collecting robotframework-seleniumlibrary
#   Downloading robotframework_seleniumlibrary-6.8.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting selenium>=4.3.0 (from robotframework-seleniumlibrary)
#   Downloading selenium-4.41.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: robotframework>=4.1.3 in c:\users\darla\anaconda3\lib\site-packages (from robotframework-seleniumlibrary) (7.4.1)
# Collecting robotframework-pythonlibcore>=4.4.1 (from robotframework-seleniumlibrary)
#   Downloading robotframework_pythonlibcore-4.5.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: click>=8.0 in c:\users\darla\anaconda3\lib\site-packages (from robotframework-seleniumlibrary) (8.1.7)
# Requirement already satisfied: colorama in c:\users\darla\anaconda3\lib\site-packages (from click>=8.0->robotframework-seleniumlibrary) (0.4.6)
# Collecting certifi>=2026.1.4 (from selenium>=4.3.0->robotframework-seleniumlibrary)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium>=4.3.0->robotframework-seleniumlibrary)
#   Downloading trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium>=4.3.0->robotframework-seleniumlibrary)
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\darla\anaconda3\lib\site-packages (from selenium>=4.3.0->robotframework-seleniumlibrary) (4.15.0)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium>=4.3.0->robotframework-seleniumlibrary)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\darla\anaconda3\lib\site-packages (from selenium>=4.3.0->robotframework-seleniumlibrary) (1.8.0)
# Collecting attrs>=23.2.0 (from trio<1.0,>=0.31.0->selenium>=4.3.0->robotframework-seleniumlibrary)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sortedcontainers in c:\users\darla\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.3.0->robotframework-seleniumlibrary) (2.4.0)
# Requirement already satisfied: idna in c:\users\darla\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.3.0->robotframework-seleniumlibrary) (3.7)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium>=4.3.0->robotframework-seleniumlibrary)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\darla\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.3.0->robotframework-seleniumlibrary) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\darla\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.3.0->robotframework-seleniumlibrary) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium>=4.3.0->robotframework-seleniumlibrary)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\darla\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium>=4.3.0->robotframework-seleniumlibrary) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\darla\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium>=4.3.0->robotframework-seleniumlibrary) (2.21)
# Collecting h11<1,>=0.16.0 (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium>=4.3.0->robotframework-seleniumlibrary)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Downloading robotframework_seleniumlibrary-6.8.0-py3-none-any.whl (104 kB)
# Downloading robotframework_pythonlibcore-4.5.0-py3-none-any.whl (19 kB)
# Downloading selenium-4.41.0-py3-none-any.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.5 MB 10.7 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 11.9 MB/s eta 0:00:00
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading trio-0.33.0-py3-none-any.whl (510 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: urllib3, robotframework-pythonlibcore, h11, certifi, attrs, wsproto, outcome, trio, trio-websocket, selenium, robotframework-seleniumlibrary
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.1.31
#     Uninstalling certifi-2025.1.31:
#       Successfully uninstalled certifi-2025.1.31
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-25.4.0 certifi-2026.2.25 h11-0.16.0 outcome-1.3.0.post0 robotframework-pythonlibcore-4.5.0 robotframework-seleniumlibrary-6.8.0 selenium-4.41.0 trio-0.33.0 trio-websocket-0.12.2 urllib3-2.6.3 wsproto-1.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# httpcore 1.0.2 requires h11<0.15,>=0.13, but you have h11 0.16.0 which is incompatible.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 6.33.2 which is incompatible.

# %%
# %%writefile indeed_tests.robot
#
# *** Settings ***
# Library    SeleniumLibrary
# Suite Setup    Open Browser To Indeed
# Suite Teardown    Close Browser
# Test Setup    Go To    https://fr.indeed.com
#
# *** Variables ***
# ${URL}    https://fr.indeed.com
# ${BROWSER}    Chrome
# ${SEARCH_TERM}    informatique
# ${LOCATION}    Paris
#
# *** Keywords ***
# Open Browser To Indeed
#     Open Browser    ${URL}    ${BROWSER}
#     Maximize Browser Window
#     Set Selenium Timeout    15 seconds
#
# Accept Cookies
#     Run Keyword And Ignore Error
#     ...    Click Button    id=onetrust-accept-btn-handler
#
# Launch Job Search
#     Accept Cookies
#     Wait Until Element Is Visible    name=q
#     Input Text    name=q    ${SEARCH_TERM}
#     Input Text    name=l    ${LOCATION}
#     Press Keys    name=l    RETURN
#     Wait Until Element Is Visible    css=div.job_seen_beacon
#
# *** Test Cases ***
# Test Homepage Load
#     Wait Until Page Contains Element    tag=body
#
# Test Page Title
#     Title Should Contain    Indeed
#
# Test Search Fields Presence
#     Accept Cookies
#     Element Should Be Visible    name=q
#     Element Should Be Visible    name=l
#
# Test Job Search
#     Launch Job Search
#
# Test First Result Contains Title
#     Launch Job Search
#     Wait Until Element Is Visible    css=h2.jobTitle
#
# Test Click First Job
#     Launch Job Search
#     Click Element    css=h2.jobTitle a
#
# Test Pagination
#     Launch Job Search
#     Click Element    css=a[aria-label="Suivant"]
#
# Test Navigation Companies Page
#     Accept Cookies
#     Click Element    partial link=Entreprises
#     Wait Until Page Contains Element    tag=body
# Out:
# Writing indeed_tests.robot

# %%
# !robot indeed_tests.robot
# Out:
# ==============================================================================
# Indeed Tests
# ==============================================================================
# Test Homepage Load                                                    | PASS |
# ------------------------------------------------------------------------------
# Test Page Title                                                       | FAIL |
# No keyword with name 'Title Should Contain' found. Did you mean:
#     SeleniumLibrary.Table Should Contain
# ------------------------------------------------------------------------------
# Test Search Fields Presence                                           | FAIL |
# Element with locator 'name=q' not found.
# ------------------------------------------------------------------------------
# Test Job Search                                                       | FAIL |
# Element 'name=q' not visible after 15 seconds.
# ------------------------------------------------------------------------------
# Test First Result Contains Title                                      | FAIL |
# Element 'name=q' not visible after 15 seconds.
# ------------------------------------------------------------------------------
# Test Click First Job                                                  | FAIL |
# Element 'name=q' not visible after 15 seconds.
# ------------------------------------------------------------------------------
# Test Pagination                                                       | FAIL |
# Element 'name=q' not visible after 15 seconds.
# ------------------------------------------------------------------------------
# Test Navigation Companies Page                                        | FAIL |
# Element with locator 'partial link=Entreprises' not found.
# ------------------------------------------------------------------------------
# Indeed Tests                                                          | FAIL |
# 8 tests, 1 passed, 7 failed
# ==============================================================================
# Output:  c:\Users\darla\Desktop\Ecran large\output.xml
# Log:     c:\Users\darla\Desktop\Ecran large\log.html
# Report:  c:\Users\darla\Desktop\Ecran large\report.html
