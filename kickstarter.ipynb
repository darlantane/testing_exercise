# %%
# !pip install robotframework
# !pip install robotframework-seleniumlibrary
# !pip install webdriver-manager

# %%
robot_code = """
*** Settings ***
Library    SeleniumLibrary

*** Variables ***
${URL}    https://www.kickstarter.com/?lang=fr
${BROWSER}    Chrome

*** Test Cases ***
Rechercher Ankama Sur Kickstarter
    Open Browser    ${URL}    ${BROWSER}
    Maximize Browser Window
    Wait Until Element Is Visible    xpath=//*[@id='global-nav-search-input']    15s
    Input Text    xpath=//*[@id='global-nav-search-input']    Ankama
    Press Keys    xpath=//*[@id='global-nav-search-input']    ENTER
    Wait Until Element Is Visible    css=div[data-test-id='project-card']    15s
    
    ${projets}=    Get WebElements    css=div[data-test-id='project-card']
    
    FOR    ${index}    IN RANGE    0    5
        ${titre}=    Get Text    xpath=(//div[@data-test-id='project-card']//h3)[${index + 1}]
        Log To Console    ${titre}
    END

    Sleep    5s
    Close Browser
"""

with open("kickstarter.robot", "w", encoding="utf-8") as f:
    f.write(robot_code)

# %%
# !robot kickstarter.robot
# Out:
# ...
# Kickstarter
# ...
# Rechercher Ankama Sur Kickstarter                                     | FAIL |
# WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=145.0.7632.76)
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff75e29aa55
# 	0x7ff75dff8630
# 	0x7ff75dd8d75d
# 	0x7ff75dd8a294
# 	0x7ff75dd7a6a1
# 	0x7ff75dd7c58f
# 	0x7ff75dd7ac41
# 	0x7ff75dd7a40b
# 	0x7ff75dd7a0c1
# 	0x7ff75dd77d0b
# 	0x7ff75dd78452
# 	0x7ff75dd91a06
# 	0x7ff75de36734
# 	0x7ff75de119da
# 	0x7ff75de3591c
# 	0x7ff75ddd9098
# 	0x7ff75ddd9f83
# 	0x7ff75e2c7810
# 	0x7ff75e2c1afd
# 	0x7ff75e2e2c1a
# 	0x7ff75e013345
# 	0x7ff75e01b81c
# 	0x7ff75e001924
# 	0x7ff75e001ad6
# 	0x7ff75dfe7e47
# 	0x7ff885b6e8d7
# 	0x7ff887a8c53c
# ------------------------------------------------------------------------------
# Kickstarter                                                           | FAIL |
# 1 test, 0 passed, 1 failed
# ...
